# %%
import music21

# %%
#load and convert the midi files using music21
gan_final_mov = music21.converter.parse('gan_final_mov.mid')

gan_midi = music21.converter.parse('gan_midi.mid')

lstm_mov = music21.converter.parse('lstm_mov.mid')

midi_song_lstm = music21.converter.parse('midi_song_lstm.mid')

# %%
gan_final_mov.plot('horizontalbar')

# %%
gan_midi.plot('horizontalbar')

# %%
lstm_mov.plot('horizontalbar')

# %%
midi_song_lstm.plot('horizontalbar')
